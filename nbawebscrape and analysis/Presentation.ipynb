# %% [markdown]
# #### Run these on your Mac: python2.7 -m pip install scipy, matplotlib, seaborn, pandas

# %%
    import sys
    sys.version
    sys.version_info
# Out:
# sys.version_info(major=2, minor=7, micro=13, releaselevel='final', serial=0)

# %%
# %run nbaanalysis.py
# Out:
# nbaanalysis.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   t['W-L'][n] = str(t['W'][n]) + '-' + str(t['L'][n])
# /usr/local/lib/python2.7/site-packages/scipy/stats/stats.py:245: RuntimeWarning: The input array could not be properly checked for nan values. nan values will be ignored.
#   "values. nan values will be ignored.", RuntimeWarning)
# /usr/local/lib/python2.7/site-packages/numpy/lib/function_base.py:3183: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[:, None]
# /usr/local/lib/python2.7/site-packages/numpy/lib/function_base.py:3184: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[None, :]
# /usr/local/lib/python2.7/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
# ...

# %%
# %matplotlib inline

# %%
x = twinratiocorr[0.99 > abs(twinratiocorr['WIN%'])]
x = x[abs(x['WIN%'])>0.5]
print('TEAM Correlations')
x
# Out:
# TEAM Correlations
#           WIN%
# +/-   0.954684
# FG%   0.670365
# 3P%   0.596784
# PTS   0.557082
# BLKA -0.501282

# %%
print 'TEAMS Block Attempts vs. Win%'
plotTeamsWinper("BLKA")
# Out:
# TEAMS Block Attempts vs. Win%

# %%
pwinratiocorr
# Out:
#           WIN%
# WIN%  1.000000
# W     0.491680
# +/-   0.482261
# AGE   0.123314
# AST   0.050738
# STL   0.050198
# 3PM   0.046483
# TD3   0.041747
# GP    0.041544
# DD2   0.025867
# 3PA   0.024952
# BLK   0.023799
# FG%   0.013422
# PTS   0.012380
# FTM   0.007194
# FGM   0.005633
# TOV  -0.001690
# FTA  -0.002276
# FT%  -0.003431
# DREB -0.004879
# 3P%  -0.005430
# REB  -0.016182
# FGA  -0.019671
# MIN  -0.026612
# OREB -0.036755
# PF   -0.039751
# L    -0.458328

# %%
plotPlayersWinper("+/-")

# %%
plotTeamWFactors("GSW")
# Out:
# GSW
# RECORD:44-8
#    STATVAR  W/Lktcorr  absktcorr    ktpval  W/Lsmcorr  abssmcorr    smpval
# 7      3P%   0.454522   0.454522  0.000089   0.548863   0.548863  0.000025
# 14     AST   0.429617   0.429617  0.000276   0.509294   0.509294  0.000115
# 2      FGM   0.374500   0.374500  0.001486   0.444920   0.444920  0.000950
# /usr/local/lib/python2.7/site-packages/matplotlib/contour.py:960: UserWarning: The following kwargs were not used by contour: 'color', 'label'
#   s)

# %%
plotTeamLFactors("GSW")
# Out:
# GSW
# RECORD:44-8
#    STATVAR  W/Lktcorr  absktcorr    ktpval  W/Lsmcorr  abssmcorr    smpval
# 10     FT%   0.232321   0.232321  0.045050   0.280642   0.280642  0.043879
# 17     TOV  -0.320719   0.320719  0.007418  -0.374924   0.374924  0.006171
# 0      MIN  -0.576381   0.576381  0.000034  -0.580061   0.580061  0.000007
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-16-d04b1380ef03> in <module>()
# ----> 1 plotTeamLFactors("GSW")
#
# /Users/benjaminsharvey/Documents/GitHub/NBA_Player_Team_Analysis/nbawebscrape and analysis/nbaanalysis.py in plotTeamLFactors(x, size)
#     320     g.map_upper(plt.scatter)
#     321     g.map_diag(plt.hist)
# --> 322     g.map_lower(sns.kdeplot)
#     323     g.add_legend()
#     324     g.fig.suptitle(x, fontsize=20)
#
# /usr/local/lib/python2.7/site-packages/seaborn/axisgrid.pyc in map_lower(self, func, **kwargs)
# ...

# %%
plotTeamWFactBox("GSW")
# Out:
# GSW
# RECORD:44-8
#   STATVAR  W/Lktcorr  absktcorr    ktpval  W/Lsmcorr  abssmcorr    smpval
# 7     3P%   0.454522   0.454522  0.000089   0.548863   0.548863  0.000025

# %%
plotTeamLFactBox("GSW")
# Out:
# GSW
# RECORD:44-8
#   STATVAR  W/Lktcorr  absktcorr    ktpval  W/Lsmcorr  abssmcorr    smpval
# 0     MIN  -0.576381   0.576381  0.000034  -0.580061   0.580061  0.000007

# %%
plotTeamHomeFactors("GSW")
# Out:
# GSW
# RECORD:44-8
#   STATVAR  ARENAktcorr  absktcorr    ktpval  ARENAsmcorr  abssmcorr    smpval
# 7     3P%     0.352397   0.352397  0.002374     0.425541   0.425541  0.001661
# 2     FGM     0.341583   0.341583  0.003754     0.405814   0.405814  0.002837
# 4     FG%     0.306755   0.306755  0.008160     0.370426   0.370426  0.006869

# %%
print rosterOrderbyImpact("GSW")
print rosterOrderbyPosImpact("GSW")
print rosterOrderbyNegImpact("GSW")
print rosterOrderbyHomeImpact("GSW")
print rosterOrderbyAwayImpact("GSW")
# Out:
# ['Draymond Green', 'Klay Thompson', 'Stephen Curry', 'Kevin Durant', 'Andre Iguodala', 'Shaun Livingston', 'David West', 'Ian Clark', 'Zaza Pachulia', 'JaVale McGee', 'Anderson Varejao', 'Patrick McCaw', 'Kevon Looney', 'James Michael McAdoo', 'Briante Weber', 'Damian Jones']
# ['Klay Thompson', 'Draymond Green', 'Kevin Durant', 'Stephen Curry', 'Andre Iguodala', 'Ian Clark', 'Shaun Livingston', 'Zaza Pachulia', 'JaVale McGee', 'David West', 'Anderson Varejao', 'Patrick McCaw', 'Kevon Looney', 'James Michael McAdoo', 'Briante Weber', 'Damian Jones']
# ['Draymond Green', 'Stephen Curry', 'Klay Thompson', 'Shaun Livingston', 'Kevin Durant', 'Andre Iguodala', 'David West', 'Anderson Varejao', 'Ian Clark', 'JaVale McGee', 'Zaza Pachulia', 'Patrick McCaw', 'Kevon Looney', 'James Michael McAdoo', 'Briante Weber', 'Damian Jones']
# ...

# %%
plotPlayerWFactors("Klay Thompson")
# Out:
# Klay Thompson
#    STATVAR  W/Lktcorr  absktcorr    ktpval  W/Lsmcorr  abssmcorr    smpval
# 19     +/-   0.490760   0.490760  0.000021   0.589617   0.589617  0.000003
# 4      FG%   0.289008   0.289008  0.012050   0.348169   0.348169  0.010626
# 7      3P%   0.262071   0.262071  0.024251   0.312453   0.312453  0.022738

# %%
plotPlayerLFactors("Draymond Green")
# Out:
# Draymond Green
#    STATVAR  W/Lktcorr  absktcorr    ktpval  W/Lsmcorr  abssmcorr    smpval
# 1      PTS  -0.258421   0.258421  0.030162  -0.306595   0.306595  0.028652
# 17     TOV  -0.272254   0.272254  0.030723  -0.305562   0.305562  0.029221
# 2      FGM  -0.293177   0.293177  0.017649  -0.335579   0.335579  0.016068

# %%
plotPlayerHomeFactors("Klay Thompson")
# Out:
# Klay Thompson
#   STATVAR  ARENAktcorr  absktcorr    ktpval  ARENAsmcorr  abssmcorr    smpval
# 4     FG%     0.334487   0.334487  0.003664     0.402957   0.402957  0.002775
# 7     3P%     0.294891   0.294891  0.011235     0.351582   0.351582  0.009837

# %%
plotPlayerWFactBox("Klay Thompson")
# Out:
# Klay Thompson
#    STATVAR  W/Lktcorr  absktcorr    ktpval  W/Lsmcorr  abssmcorr    smpval
# 19     +/-    0.49076    0.49076  0.000021   0.589617   0.589617  0.000003

# %%
plotPlayerLFactBox("Draymond Green")
# Out:
# Draymond Green
#   STATVAR  W/Lktcorr  absktcorr    ktpval  W/Lsmcorr  abssmcorr    smpval
# 2     FGM  -0.293177   0.293177  0.017649  -0.335579   0.335579  0.016068

# %%
print rosterOrderbyImpact("CLE")
print rosterOrderbyPosImpact("CLE")
print rosterOrderbyNegImpact("CLE")
print rosterOrderbyHomeImpact("CLE")
print rosterOrderbyAwayImpact("CLE")
# Out:
# ['Kyle Korver', 'Kyrie Irving', 'LeBron James', 'Kevin Love', 'Richard Jefferson', 'Jordan McRae', 'Tristan Thompson', 'Iman Shumpert', 'Kay Felder', 'JR Smith', 'Channing Frye', 'Derrick Williams', 'DeAndre Liggins', 'James Jones', 'Chris Andersen']
# ['Kyle Korver', 'Kyrie Irving', 'LeBron James', 'Kevin Love', 'Tristan Thompson', 'Richard Jefferson', 'Iman Shumpert', 'Channing Frye', 'JR Smith', 'DeAndre Liggins', 'Kay Felder', 'Derrick Williams', 'Jordan McRae', 'James Jones', 'Chris Andersen']
# ['Jordan McRae', 'Derrick Williams', 'Kay Felder', 'Kyrie Irving', 'Richard Jefferson', 'LeBron James', 'JR Smith', 'Kevin Love', 'Kyle Korver', 'Channing Frye', 'Tristan Thompson', 'Iman Shumpert', 'James Jones', 'DeAndre Liggins', 'Chris Andersen']
# ...

# %%
plotPlayerLFactors("LeBron James")
# Out:
# LeBron James
#    STATVAR  W/Lktcorr  absktcorr        ktpval  W/Lsmcorr  abssmcorr  \
# 19     +/-   0.592640   0.592640  6.027381e-07   0.712905   0.712905
# 14     AST   0.255911   0.255911  3.493922e-02   0.301295   0.301295
# 17     TOV  -0.268126   0.268126  3.310632e-02  -0.304399   0.304399
#
#           smpval
# 19  6.312198e-09
# 14  3.348058e-02
# 17  3.161258e-02

# %%
plotPlayerWFactBox("LeBron James")
# Out:
# LeBron James
#    STATVAR  W/Lktcorr  absktcorr        ktpval  W/Lsmcorr  abssmcorr  \
# 19     +/-    0.59264    0.59264  6.027381e-07   0.712905   0.712905
#
#           smpval
# 19  6.312198e-09
